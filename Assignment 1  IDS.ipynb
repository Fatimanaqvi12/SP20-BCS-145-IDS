# %%
import requests
from bs4 import BeautifulSoup
response = requests.get("https://www.libertybooks.com/index.php?route=common/home")

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'<!DOCTYPE html>\n<!--[if IE]><![endif]-->\n<!--[if IE 8 ]>\n<html dir="ltr" lang="en" class="ie8"><![endif]-->\n<!--[if IE 9 ]>\n<html dir="ltr" lang="en" class="ie9"><![endif]-->\n<!--[if (gt IE 9)|!(IE)]><!-->\n<html dir="ltr" lang="en">\n<!--<![endif]-->\n<head prefix="og:http://ogp.me/ns# fb:http://ogp.me/ns/fb# product:http://ogp.me/ns/product#">\n    <meta charset="UTF-8"/>\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <title>Liberty Books : Pakistan\'s Largest Online BookStores</title>\n    <base href="https://www.libertybooks.com/"/>\n        <meta name="description" content="Liberty Books : Pakistan\'s Largest Online BookStores"/>\n        \n    <script src="https://www.libertybooks.com/catalog/view/javascript/jquery/jquery-2.1.1.min.js?v3.9.70" type="text/javascript"></script>\n    <script src="https://www.libertybooks.com/catalog/view/javascript/bootstrap/js/bootstrap.min.js?v3.9.
# ...

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<!--[if IE]><![endif]-->\n<!--[if IE 8 ]>\n<html dir="ltr" lang="en" class="ie8"><![endif]-->\n<!--[if IE 9 ]>\n<html dir="ltr" lang="en" class="ie9"><![endif]-->\n<!--[if (gt IE 9)|!(IE)]><!-->\n<html dir="ltr" lang="en">\n<!--<![endif]-->\n<head prefix="og:http://ogp.me/ns# fb:http://ogp.me/ns/fb# product:http://ogp.me/ns/product#">\n    <meta charset="UTF-8"/>\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <title>Liberty Books : Pakistan\'s Largest Online BookStores</title>\n    <base href="https://www.libertybooks.com/"/>\n        <meta name="description" content="Liberty Books : Pakistan\'s Largest Online BookStores"/>\n        \n    <script src="https://www.libertybooks.com/catalog/view/javascript/jquery/jquery-2.1.1.min.js?v3.9.70" type="text/javascript"></script>\n    <script src="https://www.libertybooks.com/catalog/view/javascript/bootstrap/js/bootstrap.min.js?v3.9.7
# ...

# %%
response.headers
# Out:
# {'Server': 'nginx/1.21.3', 'Date': 'Sat, 24 Sep 2022 10:02:08 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Expires': 'Thu, 19 Nov 1981 08:52:00 GMT', 'Cache-Control': 'no-store, no-cache, must-revalidate, post-check=0, pre-check=0', 'Pragma': 'no-cache', 'Set-Cookie': 'city=deleted; expires=Thu, 01-Jan-1970 00:00:01 GMT; Max-Age=0; path=/, PHPSESSID=0p79bsj3tsdmu4eemjj59iepa2; path=/; HttpOnly, default=jbmi0g4gklpkc3k5k6n92ln8i6; path=/; httponly, language=en-gb; expires=Mon, 24-Oct-2022 10:02:08 GMT; Max-Age=2592000; path=/; domain=www.libertybooks.com, currency=PKR; expires=Mon, 24-Oct-2022 10:02:08 GMT; Max-Age=2592000; path=/; domain=www.libertybooks.com', 'Vary': 'Accept-Encoding,User-Agent', 'X-Frame-Options': 'SAMEORIGIN'}

# %%
response.headers['Server']
# Out:
# 'nginx/1.21.3'

# %%
response = requests.get("https://www.libertybooks.com/index.php?route=common/home")
root = BeautifulSoup(response.content, 'html5lib')
print(root.prettify())
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       1 response = requests.get("https://www.libertybooks.com/index.php?route=common/home")
# ----> 2 root = BeautifulSoup(response.content, 'html5lib')
#       3 print(root.prettify())
#
# File F:\anaconda\lib\site-packages\bs4\__init__.py:248, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     246     builder_class = builder_registry.lookup(*features)
#     247     if builder_class is None:
# --> 248         raise FeatureNotFound(
#     249             "Couldn't find a tree builder with the features you "
#     250             "requested: %s. Do you need to install a parser library?"
#     251             % ",".join(features))
#     253 # At this point either we have a TreeBuilder instance in
# ...

# %%
for row in table.findAll('img'):
  quote = {}
  quote = row['alt'].split(" #")[0]
  quotes.append(quote)

for q in quotes:
  print(q)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 for row in table.findAll('img'):
#       2   quote = {}
#       3   quote = row['alt'].split(" #")[0]
#
# NameError: name 'table' is not defined

# %%
response = requests.get("https://www.libertybooks.com/index.php?route=common/home")
root = BeautifulSoup(response.headers, 'html5lib')
print(root.prettify())
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       1 response = requests.get("https://www.libertybooks.com/index.php?route=common/home")
# ----> 2 root = BeautifulSoup(response.headers, 'html5lib')
#       3 print(root.prettify())
#
# File F:\anaconda\lib\site-packages\bs4\__init__.py:248, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     246     builder_class = builder_registry.lookup(*features)
#     247     if builder_class is None:
# --> 248         raise FeatureNotFound(
#     249             "Couldn't find a tree builder with the features you "
#     250             "requested: %s. Do you need to install a parser library?"
#     251             % ",".join(features))
#     253 # At this point either we have a TreeBuilder instance in
# ...

# %%
from bs4 import BeautifulSoup
root = BeautifulSoup(response.title, 'html.parser')
print(root.prettify())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [37], in <cell line: 2>()
#       1 from bs4 import BeautifulSoup
# ----> 2 root = BeautifulSoup(response.title, 'html.parser')
#       3 print(root.prettify())
#
# AttributeError: 'Response' object has no attribute 'title'

# %%
blog_titles = soup.select('h2.blog-card__content-title')
for title in blog_titles:
    print(title.text)

# %%
from bs4 import BeautifulSoup



    soup = BeautifulSoup(contents, features="html.parser")

    for child in soup.descendants:

        if child.name:
            print(child.name)
# Out:
#   Input In [15]
#     soup = BeautifulSoup(contents, features="html.parser")
#     ^
# IndentationError: unexpected indent

# %%
   soup = BeautifulSoup(response.content, features="html.parser")

# %%
# Out:
# <!DOCTYPE html>
# <!--[if IE]><![endif]-->
# <!--[if IE 8 ]>
# <html dir="ltr" lang="en" class="ie8"><![endif]-->
# <!--[if IE 9 ]>
# <html dir="ltr" lang="en" class="ie9"><![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!-->
# <html dir="ltr" lang="en">
#  <!--<![endif]-->
#  <head prefix="og:http://ogp.me/ns# fb:http://ogp.me/ns/fb# product:http://ogp.me/ns/product#">
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    Liberty Books : Pakistan's Largest Online BookStores
#   </title>
#   <base href="https://www.libertybooks.com/"/>
#   <meta content="Liberty Books : Pakistan's Largest Online BookStores" name="description">
#    <script src="https://www.libertybooks.com/catalog/view/javascript/jquery/jquery-2.1.1.min.js?v3.9.70" type="text/javascript">
#    </script>
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.headers, 'html.parser')
print(soup.prettify())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       1 from bs4 import BeautifulSoup
# ----> 2 soup = BeautifulSoup(response.headers, 'html.parser')
#       3 print(soup.prettify())
#
# File F:\anaconda\lib\site-packages\bs4\__init__.py:326, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     324 rejections = []
#     325 success = False
# --> 326 for (self.markup, self.original_encoding, self.declared_html_encoding,
#     327  self.contains_replacement_characters) in (
#     328      self.builder.prepare_markup(
#     329          markup, from_encoding, exclude_encodings=exclude_encodings)):
#     330     self.reset()
#     331     self.builder.initialize_soup(self)
#
# ...

# %%
list(soup.children)
# Out:
# ['html',
#  '\n',
#  '[if IE]><![endif]',
#  '\n',
#  '[if IE 8 ]>\n<html dir="ltr" lang="en" class="ie8"><![endif]',
#  '\n',
#  '[if IE 9 ]>\n<html dir="ltr" lang="en" class="ie9"><![endif]',
#  '\n',
#  '[if (gt IE 9)|!(IE)]><!',
#  '\n',
#  <html dir="ltr" lang="en">
#  <!--<![endif]-->
#  <head prefix="og:http://ogp.me/ns# fb:http://ogp.me/ns/fb# product:http://ogp.me/ns/product#">
#  <meta charset="utf-8"/>
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#  <title>Liberty Books : Pakistan's Largest Online BookStores</title>
#  <base href="https://www.libertybooks.com/"/>
#  <meta content="Liberty Books : Pakistan's Largest Online BookStores" name="description">
#  <script src="https://www.libertybooks.com/catalog/view/javascript/jquery/jquery-2.1.1.min.js?v3.9.70" type="text/javascript"></script>
# ...

# %%
list(soup.children)
# Out:
# ['html',
#  '\n',
#  '[if IE]><![endif]',
#  '\n',
#  '[if IE 8 ]>\n<html dir="ltr" lang="en" class="ie8"><![endif]',
#  '\n',
#  '[if IE 9 ]>\n<html dir="ltr" lang="en" class="ie9"><![endif]',
#  '\n',
#  '[if (gt IE 9)|!(IE)]><!',
#  '\n',
#  <html dir="ltr" lang="en">
#  <!--<![endif]-->
#  <head prefix="og:http://ogp.me/ns# fb:http://ogp.me/ns/fb# product:http://ogp.me/ns/product#">
#  <meta charset="utf-8"/>
#  <meta content="width=device-width, initial-scale=1" name="viewport"/>
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#  <title>Liberty Books : Pakistan's Largest Online BookStores</title>
#  <base href="https://www.libertybooks.com/"/>
#  <meta content="Liberty Books : Pakistan's Largest Online BookStores" name="description">
#  <script src="https://www.libertybooks.com/catalog/view/javascript/jquery/jquery-2.1.1.min.js?v3.9.70" type="text/javascript"></script>
# ...

# %%
body = list(soup.children)[2]

# %%
list(body.children)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 list(body.children)
#
# File F:\anaconda\lib\site-packages\bs4\element.py:965, in NavigableString.__getattr__(self, attr)
#     963     return self
#     964 else:
# --> 965     raise AttributeError(
#     966         "'%s' object has no attribute '%s'" % (
#     967             self.__class__.__name__, attr))
#
# AttributeError: 'Comment' object has no attribute 'children'

# %%
soup = BeautifulSoup(response.content, 'html.parser')
soup.find_all('p')
# Out:
# [<p class="text-center">Your shopping cart is empty!</p>,
#  <p class="text-center">Your shopping cart is empty!</p>,
#  <p class="author">By: Seth Grahame Smith</p>,
#  <p class="price">
#  <span class="price-new">Rs 671.25</span> <span class="price-old">Rs 895.00</span>
#  <span class="price-tax">Ex Tax:Rs 671.25</span>
#  </p>,
#  <p class="author">By: Michelle Moran</p>,
#  <p class="price">
#  <span class="price-new">Rs 537.00</span> <span class="price-old">Rs 895.00</span>
#  <span class="price-tax">Ex Tax:Rs 537.00</span>
#  </p>,
#  <p class="author">By: John Sandford</p>,
#  <p class="price">
#  <span class="price-new">Rs 1,646.25</span> <span class="price-old">Rs 2,195.00</span>
#  <span class="price-tax">Ex Tax:Rs 1,646.25</span>
#  </p>,
#  <p class="author">By: Flora Fraser</p>,
#  <p class="price">
#  <span class="price-new">Rs 1,196.25</span> <span class="price-old">Rs 1,595.00</span>
#  <span class="price-tax">Ex Tax:Rs 1,196.25</span>
#  </p>,
# ...

# %%
soup.find_all('p')[0].get_text()
# Out:
# 'Your shopping cart is empty!'

# %%
soup.find('p')
# Out:
# <p class="text-center">Your shopping cart is empty!</p>

# %%
soup = BeautifulSoup(response.headers, 'html.parser')
print(soup.prettify())
soup.find_all('p')[0].get_text()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 soup = BeautifulSoup(response.headers, 'html.parser')
#       2 print(soup.prettify())
#       3 soup.find_all('p')[0].get_text()
#
# File F:\anaconda\lib\site-packages\bs4\__init__.py:326, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     324 rejections = []
#     325 success = False
# --> 326 for (self.markup, self.original_encoding, self.declared_html_encoding,
#     327  self.contains_replacement_characters) in (
#     328      self.builder.prepare_markup(
#     329          markup, from_encoding, exclude_encodings=exclude_encodings)):
#     330     self.reset()
#     331     self.builder.initialize_soup(self)
#
# ...

# %%
soup.status_code

# %%
response.header
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
# ----> 1 response.header
#
# AttributeError: 'Response' object has no attribute 'header'

# %%
response = list(soup.children)[2]

# %%
list(html.children)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 list(html.children)
#
# File F:\anaconda\lib\site-packages\bs4\element.py:965, in NavigableString.__getattr__(self, attr)
#     963     return self
#     964 else:
# --> 965     raise AttributeError(
#     966         "'%s' object has no attribute '%s'" % (
#     967             self.__class__.__name__, attr))
#
# AttributeError: 'Comment' object has no attribute 'children'

# %%
list(body.children)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 list(body.children)
#
# File F:\anaconda\lib\site-packages\bs4\element.py:965, in NavigableString.__getattr__(self, attr)
#     963     return self
#     964 else:
# --> 965     raise AttributeError(
#     966         "'%s' object has no attribute '%s'" % (
#     967             self.__class__.__name__, attr))
#
# AttributeError: 'Comment' object has no attribute 'children'

# %%
p.get_text()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 p.get_text()
#
# NameError: name 'p' is not defined

# %%
soup.find_all('p')
# Out:
# [<p class="text-center">Your shopping cart is empty!</p>,
#  <p class="text-center">Your shopping cart is empty!</p>,
#  <p class="author">By: Seth Grahame Smith</p>,
#  <p class="price">
#  <span class="price-new">Rs 671.25</span> <span class="price-old">Rs 895.00</span>
#  <span class="price-tax">Ex Tax:Rs 671.25</span>
#  </p>,
#  <p class="author">By: Michelle Moran</p>,
#  <p class="price">
#  <span class="price-new">Rs 537.00</span> <span class="price-old">Rs 895.00</span>
#  <span class="price-tax">Ex Tax:Rs 537.00</span>
#  </p>,
#  <p class="author">By: John Sandford</p>,
#  <p class="price">
#  <span class="price-new">Rs 1,646.25</span> <span class="price-old">Rs 2,195.00</span>
#  <span class="price-tax">Ex Tax:Rs 1,646.25</span>
#  </p>,
#  <p class="author">By: Flora Fraser</p>,
#  <p class="price">
#  <span class="price-new">Rs 1,196.25</span> <span class="price-old">Rs 1,595.00</span>
#  <span class="price-tax">Ex Tax:Rs 1,196.25</span>
#  </p>,
# ...

# %%
soup.find_all('p')[2].get_text()
# Out:
# 'By: Seth Grahame Smith'

# %%
soup.find('p')
# Out:
# <p class="text-center">Your shopping cart is empty!</p>

# %%
soup.find_all('p', class_='price')
# Out:
# [<p class="price">
#  <span class="price-new">Rs 671.25</span> <span class="price-old">Rs 895.00</span>
#  <span class="price-tax">Ex Tax:Rs 671.25</span>
#  </p>,
#  <p class="price">
#  <span class="price-new">Rs 537.00</span> <span class="price-old">Rs 895.00</span>
#  <span class="price-tax">Ex Tax:Rs 537.00</span>
#  </p>,
#  <p class="price">
#  <span class="price-new">Rs 1,646.25</span> <span class="price-old">Rs 2,195.00</span>
#  <span class="price-tax">Ex Tax:Rs 1,646.25</span>
#  </p>,
#  <p class="price">
#  <span class="price-new">Rs 1,196.25</span> <span class="price-old">Rs 1,595.00</span>
#  <span class="price-tax">Ex Tax:Rs 1,196.25</span>
#  </p>,
#  <p class="price">
#  <span class="price-new">Rs 787.50</span> <span class="price-old">Rs 1,050.00</span>
#  <span class="price-tax">Ex Tax:Rs 787.50</span>
#  </p>,
#  <p class="price">
#  <span class="price-new">Rs 477.00</span> <span class="price-old">Rs 795.00</span>
# ...

# %%
soup.find_all(id="spinner0")
# Out:
# [<div id="spinner0"></div>]

# %%
 print(soup.h2)
# Out:
# None

# %%
    print(soup.li)
# Out:
# <li><a href="index.php?route=information/request_a_book"><img height="35" src="https://www.libertybooks.com/image/icons/Import-a-book-2.jpg" width="106"/></a></li>

# %%
   print(soup.li.text)

# %%
 for tag in soup.find_all('li'):
        print(tag.text)
# Out:
#   03111444282
#   query@libertybooks.com
#
#
#
# Your shopping cart is empty!
#
# Fiction
#
#
# Fiction & Literature
#
#
# Film & Television Tie In
#
#
# Humor
#
#
# Historical Fiction
#
#
# Mystery
#
#
# Romance & Love Stories
#
#
# Regional Fiction
#
#
#
#
# Classics & Literature
#
#
# Humor
#
#
# Historical
#
#
# Poetry
#
#
# Philosophy & Philosophers
#
#
# Plays & Drama
#
#
# Humor
#
#
# Performing Arts
#
#
# Literature
#
#
#
#
# Young Adults
#
#
# Young Adults
#
#
# Mysteries
#
#
# Sports & Hobbies
#
#
# Biographies
#
#
#
#
# Comics & Graphic Novels
#
#
# SpiderMan
#
#
# Asterix
#
#
# TinTin
#
#
# DC
#
#
# Team Muhafiz
#
#
# Kung Fu Panda
#
#
# Batman
#
#
# LEGO
#
#
# Game Of Thrones
#
#
# Marvel
#
#
# Star Wars
#
#
# Avengers
#
#
# Sheeba Detectives
#
#
# Sandman
#
#
# Superman
#
#
#
#
#
#
# Fiction & Literature
#
#
# Film & Television Tie In
#
#
# Humor
#
#
# Historical Fiction
#
#
# Mystery
#
#
# Romance & Love Stories
#
#
# Regional Fiction
#
#
#
#
# ...

# %%
print(period)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [54], in <cell line: 1>()
# ----> 1 print(period)
#
# NameError: name 'period' is not defined

# %%
img = soup.find("img")

# %%
period_tags = seven_day.select(".tombstone-container .period-name")
periods = [pt.get_text() for pt in period_tags]
periods
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [56], in <cell line: 1>()
# ----> 1 period_tags = seven_day.select(".tombstone-container .period-name")
#       2 periods = [pt.get_text() for pt in period_tags]
#       3 periods
#
# NameError: name 'seven_day' is not defined

# %%
response.css("img::attr(data-img)").extract()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 response.css("img::attr(data-img)").extract()
#
# File F:\anaconda\lib\site-packages\bs4\element.py:965, in NavigableString.__getattr__(self, attr)
#     963     return self
#     964 else:
# --> 965     raise AttributeError(
#     966         "'%s' object has no attribute '%s'" % (
#     967             self.__class__.__name__, attr))
#
# AttributeError: 'Comment' object has no attribute 'css'

# %%
print(soup.h2)
# Out:
# None

# %%
print(soup.li)
# Out:
# <li><a href="index.php?route=information/request_a_book"><img height="35" src="https://www.libertybooks.com/image/icons/Import-a-book-2.jpg" width="106"/></a></li>

# %%
list(soup.children.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [66], in <cell line: 1>()
# ----> 1 list(soup.children.text)
#
# AttributeError: 'list_iterator' object has no attribute 'text'

# %%
rating = soup.find(class_="author").get_text()
newprice = soup.find(class_="price-new").get_text()
oldprice = soup.find(class_="price-old").get_text()
taxprice = soup.find(class_="price-tax").get_text()
print(newprice)
print(oldprice)
print(taxprice)
print(rating)
# Out:
# Rs 671.25
# Rs 895.00
# Ex Tax:Rs 671.25
# By: Seth Grahame Smith

# %%
rating = soup.find(class_="rating").get_text()
price = soup.find(class_="price")
print(rating)
print(price)
# Out:
# <p class="price">
# <span class="price-new">Rs 671.25</span> <span class="price-old">Rs 895.00</span>
# <span class="price-tax">Ex Tax:Rs 671.25</span>
# </p>

# %%
 <p class="author">By: John Sandford</p>,
# Out:
#   Input In [81]
#     <p class="author">By: John Sandford</p>,
#     ^
# SyntaxError: invalid syntax

# %%
rating = soup.find(class_="author").get_text()

print(rating)
# Out:
# By: Seth Grahame Smith

# %%
 soup.find('li').get_text()
# Out:
# ''

# %%
for item in soup.find_all('img'):
    print(item['src'])
# Out:
# https://www.libertybooks.com/image/icons/Import-a-book-2.jpg
# https://www.libertybooks.com/image/icons/pk-flat-large.png
# https://www.libertybooks.com/image/icons/phoneB.png
# https://www.libertybooks.com/image/icons/mailB.png
# https://www.libertybooks.com/image/cache/catalog/newlogoliberty-250x67.png?q6
# https://www.libertybooks.com/image/icons/web-icons-03.png
# https://www.libertybooks.com/image/icons/liberrtybooks-cart-icon.png
# https://www.libertybooks.com/image/icons/liberrtybooks-cart-icon.png
# https://www.libertybooks.com/image/cache/catalog/newlogoliberty-250x67.png?q6
# https://www.libertybooks.com/image/icons/search.png
# https://www.libertybooks.com/image/icons/liberrtybooks-cart-icon.png
# https://www.libertybooks.com/image/icons/liberrtybooks-cart-icon.png
# https://www.libertybooks.com/image/icons/web-icons-03.png
# https://www.libertybooks.com/image/cache/catalog/Saqib - AM ECOM/Banners/Desktop-Banner-40off-1600x380.jpg?q6
# ...
